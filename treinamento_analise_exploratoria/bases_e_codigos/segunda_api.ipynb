# %%
import http.client

conn = http.client.HTTPSConnection("treinamento-ndados.s3.sa-east-1.amazonaws.com")

headersList = {
 "Accept": "*/*",
 "User-Agent": "Thunder Client (https://www.thunderclient.com)" 
}

payload = ""

conn.request("GET", "/boardgames_categoricals_raw.json", payload, headersList)
response = conn.getresponse()
result = response.read()

# %%
import pandas as pd
import json

json_file = json.loads(result)

df = pd.read_json(json.dumps(json_file))

print(df.head())
# Out:
#    objectid       label  boardgamedesigner_cnt  boardgameartist_cnt  \
# 0    174430  Board Game                      1                    3
# 1    161936  Board Game                      2                    1
# 2    167791  Board Game                      1                    1
# 3    182028  Board Game                      1                    4
# 4    224517  Board Game                      3                    3
#
#    boardgamepublisher_cnt  boardgamehonor_cnt  boardgamecategory_cnt  \
# 0                       9                  23                      5
# 1                      11                  20                      2
# 2                      20                  20                      6
# 3                      13                   3                      3
# 4                       8                   6                      3
#
#    boardgamemechanic_cnt  boardgameexpansion_cnt  boardgameversion_cnt  ...  \
# 0                     12                       4                    19  ...
# 1                      8                       0                    33  ...
# 2                      9                      15                    29  ...
# 3                      5                       1                    14  ...
# 4                      8                       0                     9  ...
#
#                                    boardgamedesigner  \
# 0                                ['Isaac Childres"']
# 1                   ['Rob Daviau"', 'Matt Leacock"']
# 2                               ['Jacob Fryxelius"']
# 3                          ['Vlaada Chv\\u00e1til"']
# 4  ['Gavan Brown"', 'Matt Tolman"', 'Martin Walla...
#
#                                      boardgameartist  \
# 0  ['Alexandr Elichev', 'Josh T. McDowell', 'Alva...
# 1                                ['Chris Quilliams']
# 2                                ['Isaac Fryxelius']
# 3  ['Filip Murmak', 'Radim Pech', 'Jakub Politzer...
# 4  ['Lina Cossette', 'David Forest', 'Damien Mamm...
#
#                                   boardgamepublisher  \
# 0  ['Cephalofair Games', 'Albi', 'Asmodee', 'Feue...
# 1  ['Z-Man Games', 'Asterion Press', 'Devir', 'Fi...
# 2  ['FryxGames', 'Arclight', 'Fantasmagoria', 'Gh...
# 3  ['Czech Games Edition', 'Cranio Creations', 'D...
# 4  ['Roxley', 'BoardM Factory', 'Conclave Editora...
#
#                                       boardgamehonor  \
# 0  ['2017 Best Science Fiction or Fantasy Board G...
# 1  ['2015 Cardboard Republic Immersionist Laurel ...
# 2  ['2016 Cardboard Republic Architect Laurel Nom...
# 3  ['2015 Golden Geek Best Strategy Board Game No...
# 4  ['2018 Golden Geek Best Board Game Artwork & P...
#
#                                    boardgamecategory  \
# 0  ['Adventure', 'Exploration', 'Fantasy', 'Fight...
# 1                       ['Environmental', 'Medical']
# 2  ['Economic', 'Environmental', 'Industry / Manu...
# 3          ['Card Game', 'Civilization', 'Economic']
# 4  ['Economic', 'Industry / Manufacturing', 'Tran...
#
#                                     boardgameversion  \
# 0  ['Chinese edition', 'Czech edition', 'English ...
# 1  ['Chinese blue edition', 'Chinese red edition'...
# 2  ['Bulgarian edition', 'Chinese edition', 'Czec...
# 3  ['Chinese edition', 'Czech edition', 'English ...
# 4  ['English deluxe edition', 'English retail edi...
#
#                                    boardgamemechanic  \
# 0  ['Campaign / Battle Card Driven', 'Cooperative...
# 1  ['Action Points', 'Cooperative Game', 'Hand Ma...
# 2  ['Card Drafting', 'End Game Bonuses', 'Hand Ma...
# 3  ['Action Points', 'Auction/Bidding', 'Auction:...
# 4  ['Hand Management', 'Income', 'Loans', 'Market...
#
#                                   boardgameexpansion  \
# 0  ['Gloomhaven: Forgotten Circles', 'Gloomhaven:...
# 1                                           ['None']
# 2  ['French Championship Promo Cards (fan expansi...
# 3      ['Through the Ages: New Leaders and Wonders']
# 4                                           ['None']
#
#                                      boardgamefamily  \
# 0  ['Campaign Games', 'Components: Miniatures', '...
# 1           ['Campaign Games', 'Legacy', 'Pandemic']
# 2  ['Fryxgames Future Timeline', 'Planets: Mars',...
# 3           ['Tableau Building', 'Through the Ages']
# 4  ['Beer', 'Brass', 'Cities: Birmingham (England...
#
#                                             gamelink
# 0                       /boardgame/174430/gloomhaven
# 1         /boardgame/161936/pandemic-legacy-season-1
# 2                /boardgame/167791/terraforming-mars
# 3  /boardgame/182028/through-ages-new-story-civil...
# 4                 /boardgame/224517/brass-birmingham
#
# [5 rows x 21 columns]

# %%
object_id = list()

for linha in range(df.shape[0]):
    object_id.append(int(df['gamelink'][linha].split('/')[-2]))

df['object_id'] = object_id
df
# Out:
#        objectid       label  boardgamedesigner_cnt  boardgameartist_cnt  \
# 0        174430  Board Game                      1                    3
# 1        161936  Board Game                      2                    1
# 2        167791  Board Game                      1                    1
# 3        182028  Board Game                      1                    4
# 4        224517  Board Game                      3                    3
# ...         ...         ...                    ...                  ...
# 20011     14765  Board Game                      1                    0
# 20012      8134  Board Game                      1                    0
# 20013      2673  Board Game                      1                    0
# 20014    132322  Board Game                      1                    1
# 20015    159452  Board Game                      1                    2
#
#        boardgamepublisher_cnt  boardgamehonor_cnt  boardgamecategory_cnt  \
# 0                           9                  23                      5
# 1                          11                  20                      2
# 2                          20                  20                      6
# 3                          13                   3                      3
# 4                           8                   6                      3
# ...                       ...                 ...                    ...
# 20011                       1                   0                      1
# 20012                       2                   0                      3
# 20013                       1                   0                      1
# 20014                       1                   0                      3
# 20015                       1                   0                      2
#
#        boardgamemechanic_cnt  boardgameexpansion_cnt  boardgameversion_cnt  \
# 0                         12                       4                    19
# 1                          8                       0                    33
# 2                          9                      15                    29
# 3                          5                       1                    14
# 4                          8                       0                     9
# ...                      ...                     ...                   ...
# 20011                      1                       0                     1
# 20012                      3                       7                     4
# 20013                      0                       0                     0
# 20014                      3                       0                     1
# 20015                      3                       0                     1
#
#        ...                                    boardgameartist  \
# 0      ...  ['Alexandr Elichev', 'Josh T. McDowell', 'Alva...
# 1      ...                                ['Chris Quilliams']
# 2      ...                                ['Isaac Fryxelius']
# 3      ...  ['Filip Murmak', 'Radim Pech', 'Jakub Politzer...
# 4      ...  ['Lina Cossette', 'David Forest', 'Damien Mamm...
# ...    ...                                                ...
# 20011  ...                                   ['(Uncredited)']
# 20012  ...                                  ['Martin Redlin']
# 20013  ...                                   ['Tony Boydell']
# 20014  ...                      ['Ingela Peterson Arrhenius']
# 20015  ...                  ['Miguel Bruque', 'Evelt Yanait']
#
#                                       boardgamepublisher  \
# 0      ['Cephalofair Games', 'Albi', 'Asmodee', 'Feue...
# 1      ['Z-Man Games', 'Asterion Press', 'Devir', 'Fi...
# 2      ['FryxGames', 'Arclight', 'Fantasmagoria', 'Gh...
# 3      ['Czech Games Edition', 'Cranio Creations', 'D...
# 4      ['Roxley', 'BoardM Factory', 'Conclave Editora...
# ...                                                  ...
# 20011                                ['(Public Domain)']
# 20012                       ['Abysse Corp.', 'alphaBIT']
# 20013                      ['Surprised Stare Games Ltd']
# 20014                              ['Peaceable Kingdom']
# 20015                                      ['GDM Games']
#
#                                           boardgamehonor  \
# 0      ['2017 Best Science Fiction or Fantasy Board G...
# 1      ['2015 Cardboard Republic Immersionist Laurel ...
# 2      ['2016 Cardboard Republic Architect Laurel Nom...
# 3      ['2015 Golden Geek Best Strategy Board Game No...
# 4      ['2018 Golden Geek Best Board Game Artwork & P...
# ...                                                  ...
# 20011                                           ['None']
# 20012                                           ['None']
# 20013                                           ['None']
# 20014                                           ['None']
# 20015                                           ['None']
#
#                                        boardgamecategory  \
# 0      ['Adventure', 'Exploration', 'Fantasy', 'Fight...
# 1                           ['Environmental', 'Medical']
# 2      ['Economic', 'Environmental', 'Industry / Manu...
# 3              ['Card Game', 'Civilization', 'Economic']
# 4      ['Economic', 'Industry / Manufacturing', 'Tran...
# ...                                                  ...
# 20011                                      ['Card Game']
# 20012           ['Card Game', 'Wargame', 'World War II']
# 20013                                      ['Card Game']
# 20014              ['Animals', 'Childrens Game', 'Dice']
# 20015                            ['Card Game', 'Horror']
#
#                                         boardgameversion  \
# 0      ['Chinese edition', 'Czech edition', 'English ...
# 1      ['Chinese blue edition', 'Chinese red edition'...
# 2      ['Bulgarian edition', 'Chinese edition', 'Czec...
# 3      ['Chinese edition', 'Czech edition', 'English ...
# 4      ['English deluxe edition', 'English retail edi...
# ...                                                  ...
# 20011                          ['Public Domain edition']
# 20012  ['Allied Starter Deck English Edition', 'Axis ...
# 20013                                      ['Card Game']
# 20014                                  ['First edition']
# 20015                                  ['First edition']
#
#                                        boardgamemechanic  \
# 0      ['Campaign / Battle Card Driven', 'Cooperative...
# 1      ['Action Points', 'Cooperative Game', 'Hand Ma...
# 2      ['Card Drafting', 'End Game Bonuses', 'Hand Ma...
# 3      ['Action Points', 'Auction/Bidding', 'Auction:...
# 4      ['Hand Management', 'Income', 'Loans', 'Market...
# ...                                                  ...
# 20011                                   ['Trick-taking']
# 20012  ['Campaign / Battle Card Driven', 'Card Drafti...
# 20013                                      ['Card Game']
# 20014  ['Cooperative Game', 'Dice Rolling', 'Pattern ...
# 20015  ['Betting and Bluffing', 'Hand Management', 'P...
#
#                                       boardgameexpansion  \
# 0      ['Gloomhaven: Forgotten Circles', 'Gloomhaven:...
# 1                                               ['None']
# 2      ['French Championship Promo Cards (fan expansi...
# 3          ['Through the Ages: New Leaders and Wonders']
# 4                                               ['None']
# ...                                                  ...
# 20011                                           ['None']
# 20012  ['History of War: Fall Gelb Edition', 'History...
# 20013                                           ['None']
# 20014                                           ['None']
# 20015                                           ['None']
#
#                                          boardgamefamily  \
# 0      ['Campaign Games', 'Components: Miniatures', '...
# 1               ['Campaign Games', 'Legacy', 'Pandemic']
# 2      ['Fryxgames Future Timeline', 'Planets: Mars',...
# 3               ['Tableau Building', 'Through the Ages']
# 4      ['Beer', 'Brass', 'Cities: Birmingham (England...
# ...                                                  ...
# 20011                         ['Traditional Card Games']
# 20012                                 ['History of War']
# 20013                                      ['Card Game']
# 20014  ['Peaceable Kingdom Pre-School Skills Builder ...
# 20015  ['Crowdfunding: Verkami', 'Cthulhu Mythos', 'L...
#
#                                                 gamelink object_id
# 0                           /boardgame/174430/gloomhaven    174430
# 1             /boardgame/161936/pandemic-legacy-season-1    161936
# 2                    /boardgame/167791/terraforming-mars    167791
# 3      /boardgame/182028/through-ages-new-story-civil...    182028
# 4                     /boardgame/224517/brass-birmingham    224517
# ...                                                  ...       ...
# 20011                             /boardgame/14765/tuppi     14765
# 20012                        /boardgame/8134/history-war      8134
# 20013                    /boardgame/2673/heskeths-legacy      2673
# 20014                     /boardgame/132322/snug-bug-rug    132322
# 20015                     /boardgame/159452/wake-cthulhu    159452
#
# [20016 rows x 22 columns]

# %%
file_name = 'segunda_api.xlsx'
df.to_excel(file_name)
